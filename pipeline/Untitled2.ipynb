# %%
import pandas as pd

# %%
import sys

# %%
pd.__file__
# Out:
# '/workspaces/docker_dataengjneering_module1/pipeline/.venv/lib/python3.12/site-packages/pandas/__init__.py'

# %%
sys.executable
# Out:
# '/workspaces/docker_dataengjneering_module1/pipeline/.venv/bin/python'
